# %% [markdown]
# ************
# # Ejercicios

# %% [markdown]
# ## Ejercicios con variables

# %% [markdown]
# ### Ejercicio 0
# - Crea un variable llamada conejos y asígnale el valor 126.
# - Crea una variable llamada zanahorias y asígnale el valor 0.
# - Muestra el contenido de la variable conejos.
# - Modifica el valor de la variable conejos por 150.
# - Copia el valor de la variable conejos en la variable zanahorias.
# - Imprime el valor de las dos variables con print().
# - Modifica el valor de conejos por 250 y vuelve a mostrar las dos variables.
#
# **Solución →** [solucion_e3a.py](scripts/solucion_e3a.py)

# %% [markdown]
# ### Ejercicio 1
# Imprimir «Bienvenido a la meteorología» por pantalla.
#
# **Solución →** [solucion_e1.py](scripts/solucion_e1.py)

# %% [markdown]
# ### Ejercicio 2
# Crear dos variables numéricas, sumarlas y mostrar el resultado
#
# **Solución →** [solucion_e2.py](scripts/solucion_e2.py)

# %% [markdown]
# ### Ejercicio 3
# Mostrar el precio del IVA de un producto con un valor de 100 y su precio final.
#
# **Solución →** [solucion_e3.py](scripts/solucion_e3.py)

# %% [markdown]
# ## Ejercicios con flujos de control

# %% [markdown]
# ### Ejercicio 4
# De dos números, saber cuál es el mayor.
#
# **Solución →** [solucion_e4.py](scripts/solucion_e4.py)

# %% [markdown]
# ### Ejercicio 5
# De dos números, saber cuál es el mayor.
#
# **Solución →** [solucion_e5.py](scripts/solucion_e5.py)

# %% [markdown]
# ### Ejercicio 6
# Añadir al anterior ejercicio, que si esta entre 11 y 20, muestre otro mensaje diferente y si esta entre 21 y 30 otro mensaje.
#
# **Solución →** [solucion_e6.py](scripts/solucion_e6.py)

# %% [markdown]
# ### Ejercicio 7
# Mostrar con un `while` los números del 1 al 100.
#
# **Solución →** [solucion_e7.py](scripts/solucion_e7.py)

# %% [markdown]
# ### Ejercicio 8
# Mostrar con un `while` los números del 1 al 100.
#
# **Solución →** [solucion_e8.py](scripts/solucion_e8.py)

# %% [markdown]
# ### Ejercicio 9
# Mostrar con un `while` los números del 1 al 100.
#
# **Solución →** [solucion_e9.py](scripts/solucion_e9.py)

# %% [markdown]
# ### Ejercicio 10
# Mostrar con un `while` los números del 1 al 100.
#
# **Solución →** [solucion_e1.py](scripts/solucion_e1.py)

# %% [markdown]
# ## Ejercicios con rangos

# %% [markdown]
# ### Ejercicio 11
# Generar un rango entre 0 y 10
#
# **Solución →** [solucion_e11.py](scripts/solucion_e11.py)

# %% [markdown]
# ### Ejercicio 12
# Generar un número entre 5 y 10
#
# **Solución →** [solucion_e12.py](scripts/solucion_e12.py)

# %% [markdown]
# ### Ejercicio 13
# Generar un rango de 10 a 0.
#
# **Solución →** [solucion_e13.py](scripts/solucion_e13.py)

# %% [markdown]
# ### Ejercicio 14
# Generar un rango de 0 a 10 y de 15 a 20, incluidos el 10 y 20
#
# **Solución →** [solucion_e14.py](scripts/solucion_e14.py)

# %% [markdown]
# ### Ejercicio 15
# Generar un rango desde 0 hasta la longitud de la cadena “Hola mundo”
#
# **Solución →** [solucion_e15.py](scripts/solucion_e15.py)

# %% [markdown]
# ## Ejercicios con funciones

# %% [markdown]
# ### Ejercicio con funciones 1
# Escribí una función llamada `esPar` que reciba como parámetro un número y retorne True si el número es par o `False` si es impar. Utilizar esta función en un programa que solicite al usuario el ingreso de 10 números y que luego muestre, por separado, la suma de todos los pares y la suma de todos los impares.
#
# **Solución →** [solucion_fun1.py](scripts/solucion_fun1.py)

# %% [markdown]
# ### Ejercicio con funciones 2
# Escribí una función llamada `sumatoriaDigitos` que reciba como parámetro un número y retorne la suma de todos sus dígitos, reutilizando la estrategia utilizada en el ejercicio 36. Finalmente, escribir un algoritmo que solicite al usuario ingresar varios números hasta que ingrese el número 100, con el cual cortará la repetición. Por cada número, mostrar la suma de sus dígitos, para lo cual se llamará a la función `sumatoriaDigitos`.
#
# **Solución →** [solucion_fun2.py](scripts/solucion_fun2.py)

# %% [markdown]
# ### Ejercicio con funciones 3
# Escribí una función que reciba un `string` y retorne `True` si es un palíndromo (esto es, si se lee igual de izquierda a derecha o de derecha a izquierda), False en caso contrario. Utilizar esta función en un programa que permita al usuario ingresar palabras hasta que ingrese la palabra “fin” (suponer que todas las palabras son en minúsculas o todas en mayúsculas, de forma consistente). Al finalizar, mostrar la cantidad de palíndromos ingresados.
#
# **Solución →** [solucion_fun3.py](scripts/solucion_fun3.py)

# %% [markdown]
# ### Ejercicio con funciones 4
# Escribí un programa que permita al usuario ingresar números enteros hasta que ingrese uno cuyo dígito inicial sea el 9 (el cual no se procesará). Una vez terminada la repetición, mostrar cuántos de los números que el usuario ingresó tienen sólo dos divisores
#
# **Solución →** [solucion_fun4.py](scripts/solucion_fun4.py)

# %% [markdown]
# ## Ejercicios con ficheros

# %% [markdown]
# ### Ejercicio con ficheros 1
# * Crea un fichero que solo contenta la línea "Este es un curso sobre Python apasionante." cien veces, después de crearlo ábrelo en modo solo lectura y escribe cada línea en un nuevo fichero.
#
# **Solución →** [solucion_ef1.py](scripts/solucion_ef1.py)
